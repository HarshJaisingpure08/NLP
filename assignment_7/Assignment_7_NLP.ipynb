# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk) (2025.11.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk) (4.67.3)

# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk import pos_tag

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
text = """
Natural Language Processing is a field of Artificial Intelligence.
It helps computers understand human language.
Students are learning NLP using Python and NLTK.
"""

print(text)
# Out:
# Natural Language Processing is a field of Artificial Intelligence.
# It helps computers understand human language.
# Students are learning NLP using Python and NLTK.

# %%
import nltk

nltk.download('punkt')
nltk.download('punkt_tab')

from nltk.tokenize import sent_tokenize

sentences = sent_tokenize(text)

print("Sentences:")
print(sentences)
# Out:
# Sentences:
# ['\nNatural Language Processing is a field of Artificial Intelligence.', 'It helps computers understand human language.', 'Students are learning NLP using Python and NLTK.']
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
words = word_tokenize(text)

print("Words:")
print(words)
# Out:
# Words:
# ['Natural', 'Language', 'Processing', 'is', 'a', 'field', 'of', 'Artificial', 'Intelligence', '.', 'It', 'helps', 'computers', 'understand', 'human', 'language', '.', 'Students', 'are', 'learning', 'NLP', 'using', 'Python', 'and', 'NLTK', '.']

# %%
stop_words = set(stopwords.words('english'))

filtered_words = [w for w in words if w.lower() not in stop_words]

print("Words after removing stopwords:")
print(filtered_words)
# Out:
# Words after removing stopwords:
# ['Natural', 'Language', 'Processing', 'field', 'Artificial', 'Intelligence', '.', 'helps', 'computers', 'understand', 'human', 'language', '.', 'Students', 'learning', 'NLP', 'using', 'Python', 'NLTK', '.']

# %%
stemmer = PorterStemmer()

stemmed_words = [stemmer.stem(word) for word in filtered_words]

print("Stemmed Words:")
print(stemmed_words)
# Out:
# Stemmed Words:
# ['natur', 'languag', 'process', 'field', 'artifici', 'intellig', '.', 'help', 'comput', 'understand', 'human', 'languag', '.', 'student', 'learn', 'nlp', 'use', 'python', 'nltk', '.']

# %%
lemmatizer = WordNetLemmatizer()

lemmatized_words = [lemmatizer.lemmatize(word) for word in filtered_words]

print("Lemmatized Words:")
print(lemmatized_words)
# Out:
# Lemmatized Words:
# ['Natural', 'Language', 'Processing', 'field', 'Artificial', 'Intelligence', '.', 'help', 'computer', 'understand', 'human', 'language', '.', 'Students', 'learning', 'NLP', 'using', 'Python', 'NLTK', '.']

# %%
import nltk

nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# True

# %%
from nltk import pos_tag

pos_tags = pos_tag(words)

print("POS Tags:")
print(pos_tags)
# Out:
# POS Tags:
# [('Natural', 'JJ'), ('Language', 'NNP'), ('Processing', 'NNP'), ('is', 'VBZ'), ('a', 'DT'), ('field', 'NN'), ('of', 'IN'), ('Artificial', 'JJ'), ('Intelligence', 'NNP'), ('.', '.'), ('It', 'PRP'), ('helps', 'VBZ'), ('computers', 'NNS'), ('understand', 'VBP'), ('human', 'JJ'), ('language', 'NN'), ('.', '.'), ('Students', 'NNS'), ('are', 'VBP'), ('learning', 'VBG'), ('NLP', 'NNP'), ('using', 'VBG'), ('Python', 'NNP'), ('and', 'CC'), ('NLTK', 'NNP'), ('.', '.')]

# %%
from nltk.probability import FreqDist

freq_dist = FreqDist(filtered_words)

print("Most common words:")
print(freq_dist.most_common(5))
# Out:
# Most common words:
# [('.', 3), ('Natural', 1), ('Language', 1), ('Processing', 1), ('field', 1)]
